# %%
import pandas as pd

# %% [markdown]
# # 1. Reading Data

# %%
sales_2017=pd.read_csv("Sales Transactions-2017.csv")

# %%
sales_2017
# Out:
#              Date    Voucher               Party            Product  \
# 0        1/4/2017      Sal:1    SOLANKI PLASTICS      DONA-VAI-9100
# 1        1/4/2017      Sal:1    SOLANKI PLASTICS    LITE FOAM(1200)
# 2        1/4/2017      Sal:2  SARNESWARA TRADERS  VISHNU CHOTA WINE
# 3        1/4/2017      Sal:2  SARNESWARA TRADERS    LITE FOAM(1200)
# 4        1/4/2017      Sal:2  SARNESWARA TRADERS      DONA-VAI-9100
# ...           ...        ...                 ...                ...
# 47285  31/03/2018  Sal:10042                 Vkp        10*10 SHEET
# 47286         NaN        NaN                 NaN                NaN
# 47287         NaN        NaN                 NaN                NaN
# 47288         NaN    Total                   NaN                NaN
# 47289         NaN    Total                   NaN                NaN
#
#                 Qty          Rate           Gross        Disc  Voucher Amount
# ...

# %%
sales_2017.head(5)
# Out:
#        Date Voucher               Party            Product  Qty      Rate  \
# 0  1/4/2017   Sal:1    SOLANKI PLASTICS      DONA-VAI-9100    2  1,690.00
# 1  1/4/2017   Sal:1    SOLANKI PLASTICS    LITE FOAM(1200)    6  1,620.00
# 2  1/4/2017   Sal:2  SARNESWARA TRADERS  VISHNU CHOTA WINE  500        23
# 3  1/4/2017   Sal:2  SARNESWARA TRADERS    LITE FOAM(1200)    6  1,620.00
# 4  1/4/2017   Sal:2  SARNESWARA TRADERS      DONA-VAI-9100    5  1,690.00
#
#        Gross Disc Voucher Amount
# 0   3,380.00  NaN      13,100.00
# 1   9,720.00  NaN            NaN
# 2  11,500.00  NaN      30,990.00
# 3   9,720.00  NaN            NaN
# 4   8,450.00  NaN            NaN

# %%
sales_2017.tail(5)
# Out:
#              Date    Voucher Party      Product           Qty          Rate  \
# 47285  31/03/2018  Sal:10042   Vkp  10*10 SHEET            25           137
# 47286         NaN        NaN   NaN          NaN           NaN           NaN
# 47287         NaN        NaN   NaN          NaN           NaN           NaN
# 47288         NaN    Total     NaN          NaN    607,734.60    669,300.49
# 47289         NaN    Total     NaN          NaN  7,593,062.00  8,309,116.00
#
#                 Gross        Disc  Voucher Amount
# 47285        3,425.00         NaN        3,425.00
# 47286             NaN         NaN             NaN
# 47287             NaN         NaN             NaN
# 47288    9,953,816.13  106,607.00    9,868,583.13
# 47289  115,778,725.71  936,348.00  115,105,123.71

# %% [markdown]
# # 2.Handle Missing Values

# %%
#Identify columns with missing values and replace with mean value
# if we find NAN values first we need to fill it with zero and then fill with static values (mean,median,mode)

# %%
sales_2017.shape
# Out:
# (47290, 9)

# %%
sales_2017.columns
# Out:
# Index(['Date', 'Voucher', 'Party', 'Product', 'Qty', 'Rate', 'Gross', 'Disc',
#        'Voucher Amount'],
#       dtype='object')

# %%
sales_2017.isna().sum()
# Out:
# Date               5388
# Voucher            5375
# Party                15
# Product            5388
# Qty                5375
# Rate               5376
# Gross              5376
# Disc              44432
# Voucher Amount    35942
# dtype: int64

# %%
sales_2017.describe()
# Out:
#          Date Voucher  Party Product    Qty   Rate  Gross  Disc Voucher Amount
# count   41902   41915  47275   41902  41915  41914  41914  2858          11348
# unique    330    9993   1114     616    302    721   1547   201           4056
# top                     TP13            100     26
# freq     1345    1345   5663    1345   5860   2194   1345  1345           1345

# %%
sales_2017.fillna(0,inplace=True)

# %%
sales_2017
# Out:
#              Date    Voucher               Party            Product  \
# 0        1/4/2017      Sal:1    SOLANKI PLASTICS      DONA-VAI-9100
# 1        1/4/2017      Sal:1    SOLANKI PLASTICS    LITE FOAM(1200)
# 2        1/4/2017      Sal:2  SARNESWARA TRADERS  VISHNU CHOTA WINE
# 3        1/4/2017      Sal:2  SARNESWARA TRADERS    LITE FOAM(1200)
# 4        1/4/2017      Sal:2  SARNESWARA TRADERS      DONA-VAI-9100
# ...           ...        ...                 ...                ...
# 47285  31/03/2018  Sal:10042                 Vkp        10*10 SHEET
# 47286           0          0                   0                  0
# 47287           0          0                   0                  0
# 47288           0    Total                     0                  0
# 47289           0    Total                     0                  0
#
#                 Qty          Rate           Gross        Disc  Voucher Amount
# ...

# %%
sales_2017["Product"].unique()
# Out:
# array(['DONA-VAI-9100', 'LITE FOAM(1200)', 'VISHNU CHOTA WINE',
#        'CLASSIC ENJOY(750)', 'Vishnu 250ml', 'BLACK DOG-350ML', ' ',
#        'Loose Items', 0, '90ML RANGEELA', 'SILVER POUCH 9*12',
#        'SILVER POUCH 8*10', 'CLASSIC 250ML(100)', '14"7PLY PLATES',
#        '10*10 TEJA', 'PAPER JUICE 190ML', 'APPLE WINE', 'APPLE 300ML',
#        'FANCY IC', 'SMART BOUL LOOSE', 'TIRUMALA LEAF(9)',
#        'SOFT NAPKEENS', '14 GREEN', '10*10 MORE', '500ML PLASTIC BOULS',
#        'Classic 250ml', '100LEAF -SP', '12*18 STAR-CUT', 'NO-00',
#        '5*6 ANKIT(20MIC)', 'PP +7*9', 'PP +(8*10)', 'N0-5', 'NO-0',
#        'NO-2', 'NO-3', 'DURGA 10*12 Blue', 'LARGE BOWL-ESSFOAM',
#        'SMARTBOUL-GLA(3500)', 'SILV-CONT-450ML(150',
#        'SILV-CONT-750ML(100', 'HIGH COUNT 10*12', 'Durga 10*12 Bk',
#        'DURGA 10*12 CL', 'SMART BOWL(3500)', 'MEDIUM BOUL CLA(540',
#        'TIRUMALA-50(13*16)', 'CYCLE 10*12 BK KG', 'PRINT-10*12 CAR',
# ...
